# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
# %matplotlib inline
# import numpy and pandas
import numpy as np
import pandas as pd
import seaborn as sns
from scipy import stats
import statsmodels.api as sm
import matplotlib.pyplot as plt

# %% [markdown]
# # Challenge 1 - Analysis of Variance
#
# In this part of the lesson, we will perform an analysis of variance to determine whether the factors in our model create a significant difference in the group means. We will be examining a dataset of FIFA players. We'll start by loading the data using the code in the cell below.

# %%
# Run this code:

fifa = pd.read_csv('fifa.csv')

# %% [markdown]
# Let's examine the dataset by looking at the `head`.

# %%
# Your code here:

fifa.head()
# Out:
#                 Name  Age Nationality  Overall  Potential  \
# 0           L. Messi   31   Argentina       94         94
# 1  Cristiano Ronaldo   33    Portugal       94         94
# 2          Neymar Jr   26      Brazil       92         93
# 3             De Gea   27       Spain       91         93
# 4       K. De Bruyne   27     Belgium       91         92
#
#                   Club    Value Preferred Foot Position  Weak Foot  \
# 0         FC Barcelona  €110.5M           Left       RF        4.0
# 1             Juventus     €77M          Right       ST        4.0
# 2  Paris Saint-Germain  €118.5M          Right       LW        5.0
# 3    Manchester United     €72M          Right       GK        3.0
# 4      Manchester City    €102M          Right      RCM        5.0
#
#    Acceleration  SprintSpeed  Stamina  Strength  LongShots  Aggression  \
# 0          91.0         86.0     72.0      59.0       94.0        48.0
# ...

# %% [markdown]
# Player's values are expressed in millions of euros. We would like this column to be numeric. Therefore, let's create a numeric value column. Do this by stripping all non-numeric characters from each cell. Assign this new data to `ValueNumeric`. There is no need to multiply the value to be expressed in millions.

# %%
for i,c in fifa.iterrows():

    if 'M' in c['Value']:
        fifa.loc[i,'ValueNumeric'] = float(c['Value'].replace('€','').replace('M',''))
    
    elif 'K' in c['Value']:
        fifa.loc[i,'ValueNumeric'] = float(c['Value'].replace('€','').replace('K','')) / 1000

    elif c['Value'] == '€0':
        fifa.loc[i,'ValueNumeric'] = 0

# %%
fifa.head()
# Out:
#                 Name  Age Nationality  Overall  Potential  \
# 0           L. Messi   31   Argentina       94         94
# 1  Cristiano Ronaldo   33    Portugal       94         94
# 2          Neymar Jr   26      Brazil       92         93
# 3             De Gea   27       Spain       91         93
# 4       K. De Bruyne   27     Belgium       91         92
#
#                   Club    Value Preferred Foot Position  Weak Foot  ...  \
# 0         FC Barcelona  €110.5M           Left       RF        4.0  ...
# 1             Juventus     €77M          Right       ST        4.0  ...
# 2  Paris Saint-Germain  €118.5M          Right       LW        5.0  ...
# 3    Manchester United     €72M          Right       GK        3.0  ...
# 4      Manchester City    €102M          Right      RCM        5.0  ...
#
#    SprintSpeed  Stamina  Strength  LongShots  Aggression  Interceptions  \
# 0         86.0     72.0      59.0       94.0        48.0           22.0
# ...

# %% [markdown]
# #### We'd like to determine whether a player's preffered foot and position have an impact on their value.
#
# Using the `statsmodels` library, we are able to produce an ANOVA table without munging our data. Create an ANOVA table with value as a function of position and preferred foot. Recall that pivoting is performed by the `C` function.
#
# Hint: For columns that have a space in their name, it is best to refer to the column using the dataframe (For example: for column `A`, we will use `df['A']`).

# %%
stats.f_oneway(*[x['ValueNumeric'] for i,x in fifa.groupby('Preferred Foot')])
# Out:
# F_onewayResult(statistic=5.132593866207275, pvalue=0.02349233836415891)

# %%
# Sacamos el boxplot para ver los datos pero vemos que los outliers ensucian la visualización

_= sns.catplot(data=fifa, x='Preferred Foot', y='ValueNumeric', kind='box', height = 6)

# %%
# Ponemos límite en el eje y para verlo mejor sin los outliers

a= sns.catplot(data=fifa, x='Preferred Foot', y='ValueNumeric', kind='box', height = 6)
_=a.set(ylim=(0, 10))

# %%
stats.f_oneway(*[x['ValueNumeric'] for i,x in fifa.groupby('Position')])
# Out:
# F_onewayResult(statistic=20.78419402849849, pvalue=5.517758067220389e-96)

# %%
# Sacamos la visualización, ya cortando el eje y para obviar los outliers

a= sns.catplot(data=fifa, x='Position', y='ValueNumeric', kind='box', height=6, aspect=2)
a.set_xticklabels(rotation=90)
_=a.set(ylim=(0,20))

# %% [markdown]
# What is your conclusion from this ANOVA?

# %% [raw]
# # Your conclusions here:
#
# El pvalue obtenido de comparar el valor por pie preferido es <0.05, lo que implica que la distribución del valor no es lo significantemente parecida como para poder considerarse la misma en función del pie. Esto implica que sí hay diferencias significativas entre el valor de jugadores zurdos y diestros.
#
# El pvalue obtenido de comparar las posiciones también es <0.05, lo que implica que la distribución del valor no es lo suficientemente parecida para cada posición. Esto implica que, al haber diferencias significativas, en este caso también influiría la posición de un futbolista a la hora de determinar su valor.

# %% [markdown]
# EXTRA: si comparamos la distribución del valor de 2 posiciones cuya distribución es parecida (sacamos del gráfico anterior las posiciones 'LB' y 'RB', vemos que el pvalue del ANOVA nos sale muy alto.

# %%
stats.f_oneway(fifa[fifa['Position']=='LB']['ValueNumeric'], fifa[fifa['Position']=='RB']['ValueNumeric'])
# Out:
# F_onewayResult(statistic=0.05117250106055971, pvalue=0.8210531576978592)

# %% [markdown]
# After looking at a model of both preffered foot and position, we decide to create an ANOVA table for nationality. Create an ANOVA table for numeric value as a function of nationality.

# %%
# Your code here:

stats.f_oneway(*[x['ValueNumeric'] for i,x in fifa.groupby('Nationality')])
# Out:
# F_onewayResult(statistic=6.762478150822396, pvalue=4.840477311070824e-134)

# %%
a= sns.catplot(data=fifa, y='Nationality', x='ValueNumeric', kind='box', height=40)
_=a.set(xlim=(0,10))

# %% [markdown]
# What is your conclusion from this ANOVA?

# %% [raw]
# El pvalue obtenido de comparar el valor por pie preferido es <0.05, lo que implica que las distribucines del valor  de los jugadores por nacionalidad no son significantemente parecidas. Esto implica que, al haber diferencias significativas entre el valor de los jugadores en función de su nacionalidad, podemos concluir que la nacionalidad sí influye en el valor de un futbolista.

# %% [markdown]
# # Challenge 2 - Linear Regression
#
# Our goal with using linear regression is to create a mathematical model that will enable us to predict the outcome of one variable using one or more additional independent variables.
#
# We'll start by ensuring there are no missing values. Examine all variables for all missing values. If there are missing values in a row, remove the entire row.

# %%
# Your code here:

fifa.dropna(inplace=True)

# %% [markdown]
# Using the FIFA dataset, in the cell below, create a linear model predicting value using stamina and sprint speed. create the model using `statsmodels`. Print the model summary.
#
# Hint: remember to add an intercept to the model using the `add_constant` function.

# %%
# Your code here:
X = sm.add_constant(fifa[['Stamina', 'SprintSpeed']])
y = fifa['ValueNumeric']

# %%
model = sm.OLS(y,X).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           ValueNumeric   R-squared:                       0.048
# Model:                            OLS   Adj. R-squared:                  0.048
# Method:                 Least Squares   F-statistic:                     453.4
# Date:                Tue, 15 Jun 2021   Prob (F-statistic):          8.04e-193
# Time:                        01:09:02   Log-Likelihood:                -55952.
# No. Observations:               17918   AIC:                         1.119e+05
# Df Residuals:                   17915   BIC:                         1.119e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          -3.0700      0.197    -15.600      0.000      -3.456      -2.684
# ...

# %% [markdown]
# Report your findings from the model summary. In particular, report about the model as a whole using the F-test and how much variation is predicted by the model using the r squared.

# %%
fifa[['ValueNumeric', 'Stamina', 'SprintSpeed']].corr()
# Out:
#               ValueNumeric   Stamina  SprintSpeed
# ValueNumeric      1.000000  0.212806     0.174047
# Stamina           0.212806  1.000000     0.619422
# SprintSpeed       0.174047  0.619422     1.000000

# %%
sns.pairplot(fifa[['ValueNumeric', 'Stamina', 'SprintSpeed']])

# %% [raw]
# # Your conclusions here:
#
# La correlación que tiene el valor con las variables 'Stamina' y 'SprintSpeed' es muy baja. Es por eso que el valor de r-squared de nuestro modelo salió 0.048, no se puede predecir con una línea de regresión con esas variables tan poco correlacionadas.

# %% [markdown]
# Next, create a second regression model predicting value using potential. Create the model using `statsmodels` and print the model summary. Remember to add a constant term.

# %%
fifa.head(2)
# Out:
#                 Name  Age Nationality  Overall  Potential          Club  \
# 0           L. Messi   31   Argentina       94         94  FC Barcelona
# 1  Cristiano Ronaldo   33    Portugal       94         94      Juventus
#
#      Value Preferred Foot Position  Weak Foot  ...  SprintSpeed  Stamina  \
# 0  €110.5M           Left       RF        4.0  ...         86.0     72.0
# 1     €77M          Right       ST        4.0  ...         91.0     88.0
#
#    Strength  LongShots  Aggression  Interceptions  Positioning  Vision  \
# 0      59.0       94.0        48.0           22.0         94.0    94.0
# 1      79.0       93.0        63.0           29.0         95.0    82.0
#
#    Penalties  ValueNumeric
# 0       75.0         110.5
# 1       85.0          77.0
#
# [2 rows x 21 columns]

# %%
# Your code here:
fifa[['Potential', 'ValueNumeric']].corr()
# Out:
#               Potential  ValueNumeric
# Potential      1.000000      0.579482
# ValueNumeric   0.579482      1.000000

# %%
from scipy.optimize import curve_fit

# %%
def f(x,a,b,c):
    return a + b*x + c*x**2

# %%
result = curve_fit(f,fifa['Potential'],fifa['ValueNumeric'])
result
# Out:
# (array([ 2.29823444e+02, -6.87662305e+00,  5.13362363e-02]),
#  array([[ 7.40525606e+00, -2.05346603e-01,  1.41304709e-03],
#         [-2.05346603e-01,  5.71447038e-03, -3.94611175e-05],
#         [ 1.41304709e-03, -3.94611175e-05,  2.73466946e-07]]))

# %%
result[0][0]
# Out:
# 229.82344383169394

# %% [markdown]
# Plot a scatter plot of value vs. potential. Do you see a linear relationship?

# %%
plt.rcParams['figure.figsize'] = (12,8)

# %%
plt.scatter(fifa['Potential'],fifa['ValueNumeric'])

_=plt.plot(fifa['Potential'].sort_values(),
           f(fifa['Potential'], result[0][0], result[0][1], result[0][2]).sort_values(),
        color='red')

# %%
# Vemos que la gráfica "nos engaña" ya que la y vuelve a crecer según disminuye la x cuando llega al punto mínimo

plt.scatter(fifa['Potential'],fifa['ValueNumeric'])

_=plt.scatter(fifa['Potential'], f(fifa['Potential'], result[0][0], result[0][1], result[0][2]),
        color='red')

# %% [markdown]
# Report your findings from the model summary. In particular, report about the model as a whole using the F-test and how much variation is predicted by the model using the r squared.

# %% [markdown]
# #### Extra: prueba con un polinomio de 3er grado

# %% [raw]
# Si el polinomio es de grado impar, hay negativos por debajo del 60; si es de orden par, vuelve a aumentar el valor por debajo de 60. A continuación la prueba.

# %%
def f2(x,a,b,c,d):
    return a + b*x + c*x**2 + d*x**3

# %%
result = curve_fit(f2,fifa['Potential'],fifa['ValueNumeric'])
result
# Out:
# (array([-9.20709634e+02,  4.15188609e+01, -6.22363424e-01,  3.10371134e-03]),
#  array([[ 2.70384245e+02, -1.12903380e+01,  1.56039527e-01,
#          -7.13779737e-04],
#         [-1.12903380e+01,  4.72626328e-01, -6.54795661e-03,
#           3.00240944e-05],
#         [ 1.56039527e-01, -6.54795661e-03,  9.09365715e-05,
#          -4.17956790e-07],
#         [-7.13779737e-04,  3.00240944e-05, -4.17956790e-07,
#           1.92551260e-09]]))

# %%
plt.scatter(fifa['Potential'],fifa['ValueNumeric'])

_=plt.scatter(fifa['Potential'], f2(fifa['Potential'], result[0][0], result[0][1], result[0][2],
                                   result[0][3]), color='red')

# %% [markdown]
# #### Extra: prueba pasando el valor a escala logarítmica

# %%
fifa['ValueLog'] = fifa['ValueNumeric'].apply(lambda x: np.log(x))

# %%
fifa.isna().sum()
# Out:
# Name              0
# Age               0
# Nationality       0
# Overall           0
# Potential         0
# Club              0
# Value             0
# Preferred Foot    0
# Position          0
# Weak Foot         0
# Acceleration      0
# SprintSpeed       0
# Stamina           0
# Strength          0
# LongShots         0
# Aggression        0
# Interceptions     0
# Positioning       0
# Vision            0
# Penalties         0
# ValueNumeric      0
# ValueLog          0
# dtype: int64

# %%
# Crearemos un nuevo df sin las observaciones cuyo valor logarítmico de 'value' es 0

fifalog = fifa[fifa['ValueLog'] != 0]

# %%
# Vemos que hay una correlación lineal

sns.lmplot(data=fifalog, x='Potential', y='ValueLog')

# %% [markdown]
# ##### OJO: Pasando el valor a escala logarítmica, ni el regplot ni linregress pueden obtener una recta de regresión

# %%
sns.regplot(data=fifalog, x='Potential', y='ValueLog')
# Out:
# <AxesSubplot:xlabel='Potential', ylabel='ValueLog'>

# %%
def f4(x,a,b):
    return a + b*x

# %%
result = curve_fit(f4,fifalog['Potential'],fifalog['ValueLog'])
result
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-1d153650f5c4> in <module>
# ----> 1 result = curve_fit(f4,fifalog['Potential'],fifalog['ValueLog'])
#       2 result
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/minpack.py in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, **kwargs)
#     732     # NaNs cannot be handled
#     733     if check_finite:
# --> 734         ydata = np.asarray_chkfinite(ydata, float)
#     735     else:
#     736         ydata = np.asarray(ydata, float)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/lib/function_base.py in asarray_chkfinite(a, dtype, order)
#     483     a = asarray(a, dtype=dtype, order=order)
#     484     if a.dtype.char in typecodes['AllFloat'] and not np.isfinite(a).all():
# --> 485         raise ValueError(
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
stats.linregress(fifalog['Potential'], fifalog['ValueLog'])
# Out:
# /Users/borjatv/opt/anaconda3/lib/python3.8/site-packages/numpy/lib/function_base.py:2474: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# LinregressResult(slope=nan, intercept=nan, rvalue=nan, pvalue=nan, stderr=nan)
